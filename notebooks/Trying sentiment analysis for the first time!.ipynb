# %%
from pymongo import MongoClient
import requests
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
conn = MongoClient("localhost:27017")

# %%
# show existing database names
conn.list_database_names()
# Out:
# ['HP', 'MyAPI', 'admin', 'config', 'ironhack', 'local']

# %%
# choose database to work with
db = conn.get_database("ironhack")
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack')

# %%
# show collections inside database
db.list_collection_names()
# Out:
# ['companies', 'restaurants', 'Twitter', 'countries_small', 'books']

# %%
# choose collection to work with
collection = db.get_collection("Twitter")
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'Twitter')

# %%
# checking our collection info before making some calls
collection.find_one()
# Out:
# {'_id': ObjectId('5fc22ff0dfa555070557b086'),
#  'tweet_id': '570306133677760513',
#  'airline_sentiment': 'neutral',
#  'airline_sentiment_confidence': '1.0',
#  'negativereason': '',
#  'negativereason_confidence': '',
#  'airline': 'Virgin America',
#  'airline_sentiment_gold': '',
#  'name': 'cairdin',
#  'negativereason_gold': '',
#  'retweet_count': '0',
#  'text': '@VirginAmerica What @dhepburn said.',
#  'tweet_coord': '',
#  'tweet_created': '2015-02-24 11:35:52 -0800',
#  'tweet_location': '',
#  'user_timezone': 'Eastern Time (US & Canada)'}

# %%
# Getting what we need in order to perform a sentiment analysis. For example we will take a list with 25 tweet comments.
tw = collection.find({}, {"_id": 0, "text": 1}).limit(25)
tweets = list(tw)
tweets
# Out:
# [{'text': '@VirginAmerica What @dhepburn said.'},
#  {'text': "@VirginAmerica plus you've added commercials to the experience... tacky."},
#  {'text': "@VirginAmerica I didn't today... Must mean I need to take another trip!"},
#  {'text': '@VirginAmerica it\'s really aggressive to blast obnoxious "entertainment" in your guests\' faces &amp; they have little recourse'},
#  {'text': "@VirginAmerica and it's a really big bad thing about it"},
#  {'text': "@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.\nit's really the only bad thing about flying VA"},
#  {'text': '@VirginAmerica yes, nearly every time I fly VX this “ear worm” won’t go away :)'},
#  {'text': '@VirginAmerica Really missed a prime opportunity for Men Without Hats parody, there. https://t.co/mWpG7grEZP'},
#  {'text': "@virginamerica Well, I didn't…but NOW I DO! :-D"},
#  {'text': "@VirginAmerica it was amazing, and arrived an hour early. You're too good to me."},
#  {'text': '@VirginAmerica did you know that suicide is the second leading cause of death among teens 10-24'},
#  {'text': '@VirginAmerica I &lt;3 pretty graphics. so much better than minimal iconography. :D'},
#  {'text': "@VirginAmerica This is such a great deal! Already thinking about my 2nd trip to @Australia &amp; I haven't even gone on my 1st trip yet! ;p"},
#  {'text': "@VirginAmerica @virginmedia I'm flying your #fabulous #Seductive skies again! U take all the #stress away from travel http://t.co/ahlXHhKiyn"},
#  {'text': '@VirginAmerica Thanks!'},
#  {'text': '@VirginAmerica SFO-PDX schedule is still MIA.'},
#  {'text': "@VirginAmerica So excited for my first cross country flight LAX to MCO I've heard nothing but great things about Virgin America. #29DaysToGo"},
#  {'text': "@VirginAmerica  I flew from NYC to SFO last week and couldn't fully sit in my seat due to two large gentleman on either side of me. HELP!"},
#  {'text': 'I ❤️ flying @VirginAmerica. ☺️👍'},
#  {'text': '@VirginAmerica you know what would be amazingly awesome? BOS-FLL PLEASE!!!!!!! I want to fly with only you.'},
#  {'text': '@VirginAmerica why are your first fares in May over three times more than other carriers when all seats are available to select???'},
#  {'text': '@VirginAmerica I love this graphic. http://t.co/UT5GrRwAaA'},
#  {'text': '@VirginAmerica I love the hipster innovation. You are a feel good brand.'},
#  {'text': '@VirginAmerica will you be making BOS&gt;LAS non stop permanently anytime soon?'},
#  {'text': '@VirginAmerica you guys messed up my seating.. I reserved seating with my friends and you guys gave my seat away ... 😡 I want free internet'}]

# %%
# Inserting the dialogues into a dataframe:
tweet_phrases = [tweet['text'] for tweet in tweets]
tweet_phrases
# Out:
# ['@VirginAmerica What @dhepburn said.',
#  "@VirginAmerica plus you've added commercials to the experience... tacky.",
#  "@VirginAmerica I didn't today... Must mean I need to take another trip!",
#  '@VirginAmerica it\'s really aggressive to blast obnoxious "entertainment" in your guests\' faces &amp; they have little recourse',
#  "@VirginAmerica and it's a really big bad thing about it",
#  "@VirginAmerica seriously would pay $30 a flight for seats that didn't have this playing.\nit's really the only bad thing about flying VA",
#  '@VirginAmerica yes, nearly every time I fly VX this “ear worm” won’t go away :)',
#  '@VirginAmerica Really missed a prime opportunity for Men Without Hats parody, there. https://t.co/mWpG7grEZP',
#  "@virginamerica Well, I didn't…but NOW I DO! :-D",
#  "@VirginAmerica it was amazing, and arrived an hour early. You're too good to me.",
#  '@VirginAmerica did you know that suicide is the second leading cause of death among teens 10-24',
#  '@VirginAmerica I &lt;3 pretty graphics. so much better than minimal iconography. :D',
#  "@VirginAmerica This is such a great deal! Already thinking about my 2nd trip to @Australia &amp; I haven't even gone on my 1st trip yet! ;p",
#  "@VirginAmerica @virginmedia I'm flying your #fabulous #Seductive skies again! U take all the #stress away from travel http://t.co/ahlXHhKiyn",
#  '@VirginAmerica Thanks!',
#  '@VirginAmerica SFO-PDX schedule is still MIA.',
#  "@VirginAmerica So excited for my first cross country flight LAX to MCO I've heard nothing but great things about Virgin America. #29DaysToGo",
#  "@VirginAmerica  I flew from NYC to SFO last week and couldn't fully sit in my seat due to two large gentleman on either side of me. HELP!",
#  'I ❤️ flying @VirginAmerica. ☺️👍',
#  '@VirginAmerica you know what would be amazingly awesome? BOS-FLL PLEASE!!!!!!! I want to fly with only you.',
#  '@VirginAmerica why are your first fares in May over three times more than other carriers when all seats are available to select???',
#  '@VirginAmerica I love this graphic. http://t.co/UT5GrRwAaA',
#  '@VirginAmerica I love the hipster innovation. You are a feel good brand.',
#  '@VirginAmerica will you be making BOS&gt;LAS non stop permanently anytime soon?',
#  '@VirginAmerica you guys messed up my seating.. I reserved seating with my friends and you guys gave my seat away ... 😡 I want free internet']

# %%
tweetsdf = pd.DataFrame(tweet_phrases, columns=["Tweets"])
tweetsdf.head()
# Out:
#                                               Tweets
# 0                @VirginAmerica What @dhepburn said.
# 1  @VirginAmerica plus you've added commercials t...
# 2  @VirginAmerica I didn't today... Must mean I n...
# 3  @VirginAmerica it's really aggressive to blast...
# 4  @VirginAmerica and it's a really big bad thing...

# %%
# Loading the sentiment analyzer!
sia = SentimentIntensityAnalyzer()

# %%
sentence = "I flew from NYC to SFO last week and couldn't fully sit in my seat due to two large gentleman on either side of me. HELP!"

# %%
# Testing the sentiment analyzer:
polarity = sia.polarity_scores(sentence)
polarity
# Out:
# {'neg': 0.0, 'neu': 0.866, 'pos': 0.134, 'compound': 0.5754}

# %%
def sentimentAnalysis(sentence):
    sia = SentimentIntensityAnalyzer()
    polarity = sia.polarity_scores(sentence)
    pol = polarity['compound']
    return pol

# %%
tweetsdf['sentiment_compound'] = tweetsdf['Tweets'].apply(sentimentAnalysis)
tweetsdf
# Out:
#                                                Tweets  sentiment_compound
# 0                 @VirginAmerica What @dhepburn said.              0.0000
# 1   @VirginAmerica plus you've added commercials t...              0.0000
# 2   @VirginAmerica I didn't today... Must mean I n...              0.0000
# 3   @VirginAmerica it's really aggressive to blast...             -0.5984
# 4   @VirginAmerica and it's a really big bad thing...             -0.5829
# 5   @VirginAmerica seriously would pay $30 a fligh...             -0.5945
# 6   @VirginAmerica yes, nearly every time I fly VX...              0.6908
# 7   @VirginAmerica Really missed a prime opportuni...              0.1458
# 8     @virginamerica Well, I didn't…but NOW I DO! :-D             -0.3477
# 9   @VirginAmerica it was amazing, and arrived an ...              0.7717
# 10  @VirginAmerica did you know that suicide is th...             -0.8555
# 11  @VirginAmerica I &lt;3 pretty graphics. so muc...              0.8863
# 12  @VirginAmerica This is such a great deal! Alre...              0.6892
# 13  @VirginAmerica @virginmedia I'm flying your #f...              0.0000
# 14                             @VirginAmerica Thanks!              0.4926
# 15      @VirginAmerica SFO-PDX schedule is still MIA.             -0.4466
# 16  @VirginAmerica So excited for my first cross c...             -0.5566
# 17  @VirginAmerica  I flew from NYC to SFO last we...              0.5754
# 18                    I ❤️ flying @VirginAmerica. ☺️👍              0.0000
# 19  @VirginAmerica you know what would be amazingl...              0.7821
# 20  @VirginAmerica why are your first fares in May...              0.0000
# 21  @VirginAmerica I love this graphic. http://t.c...              0.6369
# 22  @VirginAmerica I love the hipster innovation. ...              0.8658
# 23  @VirginAmerica will you be making BOS&gt;LAS n...             -0.2960
# 24  @VirginAmerica you guys messed up my seating.....              0.6486

# %% [markdown]
# ### NOW THAT WE KNOW IT WORKS, LET'S GET WHAT WE NEED FOR OUR NEW DATABASE AND START POPULATING IT!

# %%
# We are going to select what we find useful to our new database and save it to a .json file:
data = pd.read_csv('../data/Tweets.csv')
data.sample(5)
# Out:
#                 tweet_id airline_sentiment  airline_sentiment_confidence  \
# 5457  568977492410703872          negative                        1.0000
# 8249  568558887290441728          negative                        1.0000
# 2717  568940548301549568          negative                        0.7055
# 7879  569122341797691392          negative                        1.0000
# 5784  568605955614642176          positive                        1.0000
#
#               negativereason  negativereason_confidence    airline  \
# 5457  Customer Service Issue                     0.3489  Southwest
# 8249              Bad Flight                     0.6990      Delta
# 2717             Late Flight                     0.3748     United
# 7879  Customer Service Issue                     0.6869      Delta
# 5784                     NaN                        NaN  Southwest
#
#      airline_sentiment_gold            name negativereason_gold  \
# 5457                    NaN     Julia_Pabst                 NaN
# 8249                    NaN  superhilarious                 NaN
# 2717                    NaN        wisemana                 NaN
# 7879                    NaN   JessBarbalato                 NaN
# 5784                    NaN     MattChrisEd                 NaN
#
#       retweet_count                                               text  \
# 5457              0  @SouthwestAir wanting a ⭐️ for the ✈️ finding ...
# 8249              0  @JetBlue :/ he was trying to take stuff from t...
# 2717              0  @United can you let us out of the gate now. UA...
# 7879              0  @jetblue is the website down? Can't print boar...
# 5784              0  @SouthwestAir appreciate the reply, hopefully ...
#
#      tweet_coord              tweet_created  tweet_location  \
# 5457         NaN  2015-02-20 19:36:19 -0800     Los Angeles
# 8249         NaN  2015-02-19 15:52:56 -0800             NaN
# 2717  [0.0, 0.0]  2015-02-20 17:09:31 -0800  washington, dc
# 7879         NaN  2015-02-21 05:11:54 -0800             NaN
# 5784         NaN  2015-02-19 18:59:58 -0800  City of Angels
#
#                    user_timezone
# 5457  Pacific Time (US & Canada)
# 8249  Central Time (US & Canada)
# 2717  Eastern Time (US & Canada)
# 7879  Eastern Time (US & Canada)
# 5784  Pacific Time (US & Canada)

# %%
to_drop = ['tweet_id', 'airline_sentiment', 'airline_sentiment_confidence', 'negativereason_confidence', 'airline_sentiment_gold', 'negativereason_gold', 'retweet_count', 'tweet_coord', 'tweet_created', 'user_timezone']
data.drop(to_drop, axis='columns', inplace=True)
data.head()
# Out:
#   negativereason         airline        name  \
# 0            NaN  Virgin America     cairdin
# 1            NaN  Virgin America    jnardino
# 2            NaN  Virgin America  yvonnalynn
# 3     Bad Flight  Virgin America    jnardino
# 4     Can't Tell  Virgin America    jnardino
#
#                                                 text tweet_location
# 0                @VirginAmerica What @dhepburn said.            NaN
# 1  @VirginAmerica plus you've added commercials t...            NaN
# 2  @VirginAmerica I didn't today... Must mean I n...      Lets Play
# 3  @VirginAmerica it's really aggressive to blast...            NaN
# 4  @VirginAmerica and it's a really big bad thing...            NaN

# %%
df = data.fillna('-')
new = df.sample(150)
new
# Out:
#                negativereason     airline           name  \
# 2645                        -      United    lisahsamuel
# 12849                       -    American       murraysm
# 12905             Late Flight    American         cubexg
# 7678                        -       Delta  BookerWoodfox
# 4846   Customer Service Issue   Southwest        MsNamri
# ...                       ...         ...            ...
# 11500        Cancelled Flight  US Airways    lisascott09
# 13094        Cancelled Flight    American       kayliemj
# 14237                       -    American        fritzmt
# 10947              Can't Tell  US Airways    altadenadad
# 9024                        -  US Airways       mlmoore2
#
#                                                     text  \
# 2645   @united Thank you so much for your help with m...
# 12849  @AmericanAir No snow in St. Louis. Cold but no...
# 12905  @AmericanAir stuck at gate Miami to JFK flight...
# 7678   @JetBlue is amazing. Had a short delay. They g...
# 4846   @SouthwestAir why does the customer service ha...
# ...                                                  ...
# 11500  @USAirways is useless airways. Day 2 trying to...
# 13094  @AmericanAir On hold since 5am. When no one ca...
# 14237              @AmericanAir message and pics sent...
# 10947  @USAirways Plus a US Airways - you need to do ...
# 9024   @USAirways great job today from your team with...
#
#                        tweet_location
# 2645                   Bellingham, WA
# 12849         St. Louis, Missouri USA
# 12905                        New York
# 7678                         Lynn, MA
# 4846                    Las Vegas, NV
# ...                               ...
# 11500                               -
# 13094                     Seattle, WA
# 14237                          U.S.A.
# 10947  Haverford, PA & Wilton Manors
# 9024                     Gulfport, MS
#
# [150 rows x 5 columns]

# %%
new.to_json("../data/tweets_new", orient="records")

# %%
to_fill = df.sample(150)
to_fill.to_json("../data/tweets_to_fill", orient="records")
